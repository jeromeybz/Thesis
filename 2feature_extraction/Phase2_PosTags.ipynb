# %%
pip install gdown

# %%
import pandas as pd
import gdown

# Google Drive file ID
file_id = '1i9t0O1ywpnzPk1xfF36ZAsTlpB_f0NZK'

# Generate the download link
url = f'https://drive.google.com/uc?export=download&id={file_id}'

# Download the file
output = 'file.csv'
gdown.download(url, output, quiet=False)

# Try reading the CSV with a different encoding
dataset = pd.read_csv(output, encoding='ISO-8859-1')

# Show the first few rows of the DataFrame
dataset.head()
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1i9t0O1ywpnzPk1xfF36ZAsTlpB_f0NZK
# From (redirected): https://drive.google.com/uc?export=download&id=1i9t0O1ywpnzPk1xfF36ZAsTlpB_f0NZK&confirm=t&uuid=3c864532-28e7-4cad-8b7f-4299ff386fcc
# To: /content/file.csv
# 100%|██████████| 126M/126M [00:02<00:00, 60.3MB/s]
#                                           clean_text Sentiment
# 0  is upset that he cant update his facebook by t...  negative
# 1        and might cry as a result school today also  negative
# 2                                              blah!  negative
# 3                    i dived many times for the ball  negative
# 4          managed to save the rest go out of bounds  negative

# %%
dataset
# Out:
#                                                 clean_text Sentiment
# 0        is upset that he cant update his facebook by t...  negative
# 1              and might cry as a result school today also  negative
# 2                                                    blah!  negative
# 3                          i dived many times for the ball  negative
# 4                managed to save the rest go out of bounds  negative
# ...                                                    ...       ...
# 2475053                                             thewdb  positive
# 2475054         com very cool to hear old walt interviews!  positive
# 2475055  are you ready for your mojo makeover? ask me f...  positive
# 2475056  happy th birthday to my boo of alll time! tupa...  positive
# 2475057                               happy charitytuesday  positive
#
# [2475058 rows x 2 columns]

# %%
import spacy
import pandas as pd

nlp = spacy.load('en_core_web_sm')

# spacy pos tagging
def pos_tagging_spacy(text):
    cleaned_text = clean_text(text)  
    doc = nlp(cleaned_text)  
    return [token.pos_ for token in doc] 

def clean_text(text):
    return text.lower()

df_first_3 = dataset
df_first_3['pos_tags'] = df_first_3['clean_text'].apply(pos_tagging_spacy)
result_df = df_first_3[['Sentiment', 'pos_tags']]
result_df
# Out:
#         Sentiment                                           pos_tags
# 0        negative  [AUX, ADJ, SCONJ, PRON, AUX, PART, VERB, PRON,...
# 1        negative  [CCONJ, AUX, VERB, ADP, DET, NOUN, NOUN, NOUN,...
# 2        negative                                      [INTJ, PUNCT]
# 3        negative            [PRON, VERB, ADJ, NOUN, ADP, DET, NOUN]
# 4        negative  [VERB, PART, VERB, DET, NOUN, VERB, ADP, ADP, ...
# ...           ...                                                ...
# 2475053  positive                                            [PROPN]
# 2475054  positive  [NOUN, ADV, ADJ, PART, VERB, ADJ, PROPN, NOUN,...
# 2475055  positive  [AUX, PRON, ADJ, ADP, PRON, ADJ, NOUN, PUNCT, ...
# 2475056  positive  [ADJ, NOUN, NOUN, ADP, PRON, NOUN, ADP, NOUN, ...
# 2475057  positive                                        [ADJ, NOUN]
#
# [2475058 rows x 2 columns]

# %%
result_df.to_csv('file.csv', index=False)
print("CSV file 'cleaned_dataset.csv' has been saved.")
