# %%
import pandas as pd
file_path = "D:/100k.csv"
df = pd.read_csv(file_path)
df
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5664\1540798196.py:5: DtypeWarning: Columns (29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#       Sentiment  pos_1 pos_2 pos_3  pos_4 pos_5 pos_6 pos_7 pos_8  pos_9  ...  \
# 0      negative  SCONJ   AUX  NOUN    ADP  NOUN   NaN   NaN   NaN    NaN  ...
# 1      negative   PRON  NOUN   ADV  SCONJ  VERB   ADP   ADJ  NOUN    NaN  ...
# 2      positive   INTJ  INTJ  PRON    AUX   ADV  PRON  NOUN  NOUN  CCONJ  ...
# 3      negative    AUX   ADJ   ADJ  CCONJ   AUX  VERB   ADP  NOUN   VERB  ...
# 4      negative   PRON  VERB   AUX    ADJ   NaN   NaN   NaN   NaN    NaN  ...
# ...         ...    ...   ...   ...    ...   ...   ...   ...   ...    ...  ...
# 99995  positive   VERB  PRON   ADV    ADV  NOUN   NaN   NaN   NaN    NaN  ...
# 99996  negative   PRON   AUX  VERB   PRON  NOUN   ADV   ADV   ADV   PRON  ...
# 99997  negative    AUX   ADJ  VERB    ADP  NOUN   NaN   NaN   NaN    NaN  ...
# 99998  positive   NOUN   NaN   NaN    NaN   NaN   NaN   NaN   NaN    NaN  ...
# 99999  positive  PROPN  PRON  VERB   PRON  VERB   ADJ   NaN   NaN    NaN  ...
#
#       pos_22 pos_23 pos_24 pos_25 pos_26 pos_27 pos_28 pos_29 pos_30 pos_31
# 0        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 99995    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 99996    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 99997    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 99998    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 99999    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [100000 rows x 32 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from itertools import combinations
from sklearn.model_selection import train_test_split

pos_tags = ['AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP']
pos_columns = [f'pos_{i}' for i in range(1, 32)]

results = []

for size in range(1, 12):
    print(f"\n--- Subset Size: {size} ---")
    for combo in combinations(pos_tags, size):
        combination = set(combo)
        filtered_rows = []

        for _, row in df.iterrows():
            tags = row[pos_columns].tolist()
            filtered = [tag if tag in combination else np.nan for tag in tags]
            non_nan = [tag for tag in filtered if pd.notna(tag)]
            filtered_rows.append(non_nan)

        max_len = max(len(row) for row in filtered_rows)
        if max_len == 0:
            continue

        shifted_df = pd.DataFrame([
            row + [np.nan] * (max_len - len(row)) for row in filtered_rows
        ], columns=[f'pos_{i+1}' for i in range(max_len)])

        shifted_df['Sentiment'] = df['Sentiment'].values

        # Encode
        X_full = shifted_df.drop(columns=['Sentiment']).astype(str)
        y = shifted_df['Sentiment']
        label_encoders = {}
        for col in X_full.columns:
            le = LabelEncoder()
            X_full[col] = le.fit_transform(X_full[col])
            label_encoders[col] = le

        # Train/test split and model
        X_train, X_test, y_train, y_test = train_test_split(X_full, y, test_size=0.2, random_state=42)
        model = RandomForestClassifier()
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        acc = accuracy_score(y_test, y_pred)

        print(f"Combo: {combo} -> Accuracy: {acc:.4f}")
        results.append({'combo': combo, 'accuracy': acc})

# Top 10 overall
top_10 = sorted(results, key=lambda x: x['accuracy'], reverse=True)[:10]
print("\nTop 10 Combinations:")
for i, res in enumerate(top_10, 1):
    print(f"{i}. Tags: {res['combo']} -> Accuracy: {res['accuracy']:.4f} ")

# Best per size
best_per_size = {}
for res in results:
    size = len(res['combo'])
    if size not in best_per_size or res['accuracy'] > best_per_size[size]['accuracy']:
        best_per_size[size] = res

print("\nBest combination per subset size:")
for size in sorted(best_per_size):
    res = best_per_size[size]
    print(f"Size {size}: Tags {res['combo']} -> Accuracy: {res['accuracy']:.4f} ")
# Out:
# --- Subset Size: 1 ---
# Combo: ('AUX',) -> Accuracy: 0.5298
# Combo: ('CCONJ',) -> Accuracy: 0.5085
# Combo: ('INTJ',) -> Accuracy: 0.5152
# Combo: ('PRON',) -> Accuracy: 0.5171
# Combo: ('VERB',) -> Accuracy: 0.5181
# Combo: ('SCONJ',) -> Accuracy: 0.5069
# Combo: ('ADJ',) -> Accuracy: 0.5041
# Combo: ('NOUN',) -> Accuracy: 0.5161
# Combo: ('ADV',) -> Accuracy: 0.5197
# Combo: ('PROPN',) -> Accuracy: 0.5209
# Combo: ('ADP',) -> Accuracy: 0.5081
#
# --- Subset Size: 2 ---
# Combo: ('AUX', 'CCONJ') -> Accuracy: 0.5293
# Combo: ('AUX', 'INTJ') -> Accuracy: 0.5340
# Combo: ('AUX', 'PRON') -> Accuracy: 0.5259
# Combo: ('AUX', 'VERB') -> Accuracy: 0.5314
# Combo: ('AUX', 'SCONJ') -> Accuracy: 0.5290
# Combo: ('AUX', 'ADJ') -> Accuracy: 0.5269
# Combo: ('AUX', 'NOUN') -> Accuracy: 0.5314
# Combo: ('AUX', 'ADV') -> Accuracy: 0.5318
# Combo: ('AUX', 'PROPN') -> Accuracy: 0.5311
# Combo: ('AUX', 'ADP') -> Accuracy: 0.5289
# Combo: ('CCONJ', 'INTJ') -> Accuracy: 0.5101
# Combo: ('CCONJ', 'PRON') -> Accuracy: 0.5164
# Combo: ('CCONJ', 'VERB') -> Accuracy: 0.5177
# Combo: ('CCONJ', 'SCONJ') -> Accuracy: 0.5147
# Combo: ('CCONJ', 'ADJ') -> Accuracy: 0.5091
# Combo: ('CCONJ', 'NOUN') -> Accuracy: 0.5169
# Combo: ('CCONJ', 'ADV') -> Accuracy: 0.5176
# Combo: ('CCONJ', 'PROPN') -> Accuracy: 0.5238
# Combo: ('CCONJ', 'ADP') -> Accuracy: 0.5065
# Combo: ('INTJ', 'PRON') -> Accuracy: 0.5245
# Combo: ('INTJ', 'VERB') -> Accuracy: 0.5258
# Combo: ('INTJ', 'SCONJ') -> Accuracy: 0.5090
# Combo: ('INTJ', 'ADJ') -> Accuracy: 0.5194
# Combo: ('INTJ', 'NOUN') -> Accuracy: 0.5210
# Combo: ('INTJ', 'ADV') -> Accuracy: 0.5236
# Combo: ('INTJ', 'PROPN') -> Accuracy: 0.5269
# Combo: ('INTJ', 'ADP') -> Accuracy: 0.5149
# Combo: ('PRON', 'VERB') -> Accuracy: 0.5290
# Combo: ('PRON', 'SCONJ') -> Accuracy: 0.5175
# Combo: ('PRON', 'ADJ') -> Accuracy: 0.5235
# Combo: ('PRON', 'NOUN') -> Accuracy: 0.5254
# Combo: ('PRON', 'ADV') -> Accuracy: 0.5145
# Combo: ('PRON', 'PROPN') -> Accuracy: 0.5225
# Combo: ('PRON', 'ADP') -> Accuracy: 0.5225
# Combo: ('VERB', 'SCONJ') -> Accuracy: 0.5187
# Combo: ('VERB', 'ADJ') -> Accuracy: 0.5184
# Combo: ('VERB', 'NOUN') -> Accuracy: 0.5252
# Combo: ('VERB', 'ADV') -> Accuracy: 0.5234
# Combo: ('VERB', 'PROPN') -> Accuracy: 0.5285
# Combo: ('VERB', 'ADP') -> Accuracy: 0.5228
# Combo: ('SCONJ', 'ADJ') -> Accuracy: 0.5102
# Combo: ('SCONJ', 'NOUN') -> Accuracy: 0.5164
# Combo: ('SCONJ', 'ADV') -> Accuracy: 0.5221
# Combo: ('SCONJ', 'PROPN') -> Accuracy: 0.5208
# Combo: ('SCONJ', 'ADP') -> Accuracy: 0.5061
# Combo: ('ADJ', 'NOUN') -> Accuracy: 0.5163
# Combo: ('ADJ', 'ADV') -> Accuracy: 0.5183
# Combo: ('ADJ', 'PROPN') -> Accuracy: 0.5220
# Combo: ('ADJ', 'ADP') -> Accuracy: 0.5065
# Combo: ('NOUN', 'ADV') -> Accuracy: 0.5216
# Combo: ('NOUN', 'PROPN') -> Accuracy: 0.5192
# Combo: ('NOUN', 'ADP') -> Accuracy: 0.5106
# Combo: ('ADV', 'PROPN') -> Accuracy: 0.5218
# Combo: ('ADV', 'ADP') -> Accuracy: 0.5193
# Combo: ('PROPN', 'ADP') -> Accuracy: 0.5186
#
# --- Subset Size: 3 ---
# Combo: ('AUX', 'CCONJ', 'INTJ') -> Accuracy: 0.5331
# Combo: ('AUX', 'CCONJ', 'PRON') -> Accuracy: 0.5258
# Combo: ('AUX', 'CCONJ', 'VERB') -> Accuracy: 0.5292
# Combo: ('AUX', 'CCONJ', 'SCONJ') -> Accuracy: 0.5274
# Combo: ('AUX', 'CCONJ', 'ADJ') -> Accuracy: 0.5257
# Combo: ('AUX', 'CCONJ', 'NOUN') -> Accuracy: 0.5313
# Combo: ('AUX', 'CCONJ', 'ADV') -> Accuracy: 0.5308
# Combo: ('AUX', 'CCONJ', 'PROPN') -> Accuracy: 0.5311
# Combo: ('AUX', 'CCONJ', 'ADP') -> Accuracy: 0.5276
# Combo: ('AUX', 'INTJ', 'PRON') -> Accuracy: 0.5316
# Combo: ('AUX', 'INTJ', 'VERB') -> Accuracy: 0.5326
# Combo: ('AUX', 'INTJ', 'SCONJ') -> Accuracy: 0.5325
# Combo: ('AUX', 'INTJ', 'ADJ') -> Accuracy: 0.5309
# Combo: ('AUX', 'INTJ', 'NOUN') -> Accuracy: 0.5359
# Combo: ('AUX', 'INTJ', 'ADV') -> Accuracy: 0.5373
# Combo: ('AUX', 'INTJ', 'PROPN') -> Accuracy: 0.5359
# Combo: ('AUX', 'INTJ', 'ADP') -> Accuracy: 0.5328
# Combo: ('AUX', 'PRON', 'VERB') -> Accuracy: 0.5390
# Combo: ('AUX', 'PRON', 'SCONJ') -> Accuracy: 0.5240
# Combo: ('AUX', 'PRON', 'ADJ') -> Accuracy: 0.5250
# Combo: ('AUX', 'PRON', 'NOUN') -> Accuracy: 0.5316
# Combo: ('AUX', 'PRON', 'ADV') -> Accuracy: 0.5285
# Combo: ('AUX', 'PRON', 'PROPN') -> Accuracy: 0.5285
# Combo: ('AUX', 'PRON', 'ADP') -> Accuracy: 0.5254
# Combo: ('AUX', 'VERB', 'SCONJ') -> Accuracy: 0.5326
# Combo: ('AUX', 'VERB', 'ADJ') -> Accuracy: 0.5277
# Combo: ('AUX', 'VERB', 'NOUN') -> Accuracy: 0.5332
# Combo: ('AUX', 'VERB', 'ADV') -> Accuracy: 0.5310
# Combo: ('AUX', 'VERB', 'PROPN') -> Accuracy: 0.5313
# Combo: ('AUX', 'VERB', 'ADP') -> Accuracy: 0.5191
# Combo: ('AUX', 'SCONJ', 'ADJ') -> Accuracy: 0.5257
# Combo: ('AUX', 'SCONJ', 'NOUN') -> Accuracy: 0.5302
# Combo: ('AUX', 'SCONJ', 'ADV') -> Accuracy: 0.5299
# Combo: ('AUX', 'SCONJ', 'PROPN') -> Accuracy: 0.5309
# Combo: ('AUX', 'SCONJ', 'ADP') -> Accuracy: 0.5256
# Combo: ('AUX', 'ADJ', 'NOUN') -> Accuracy: 0.5262
# Combo: ('AUX', 'ADJ', 'ADV') -> Accuracy: 0.5332
# Combo: ('AUX', 'ADJ', 'PROPN') -> Accuracy: 0.5285
# Combo: ('AUX', 'ADJ', 'ADP') -> Accuracy: 0.5240
# Combo: ('AUX', 'NOUN', 'ADV') -> Accuracy: 0.5268
# Combo: ('AUX', 'NOUN', 'PROPN') -> Accuracy: 0.5326
# Combo: ('AUX', 'NOUN', 'ADP') -> Accuracy: 0.5330
# Combo: ('AUX', 'ADV', 'PROPN') -> Accuracy: 0.5382
# Combo: ('AUX', 'ADV', 'ADP') -> Accuracy: 0.5292
# Combo: ('AUX', 'PROPN', 'ADP') -> Accuracy: 0.5267
# Combo: ('CCONJ', 'INTJ', 'PRON') -> Accuracy: 0.5227
# Combo: ('CCONJ', 'INTJ', 'VERB') -> Accuracy: 0.5248
# Combo: ('CCONJ', 'INTJ', 'SCONJ') -> Accuracy: 0.5173
# Combo: ('CCONJ', 'INTJ', 'ADJ') -> Accuracy: 0.5170
# Combo: ('CCONJ', 'INTJ', 'NOUN') -> Accuracy: 0.5270
# Combo: ('CCONJ', 'INTJ', 'ADV') -> Accuracy: 0.5224
# Combo: ('CCONJ', 'INTJ', 'PROPN') -> Accuracy: 0.5302
# Combo: ('CCONJ', 'INTJ', 'ADP') -> Accuracy: 0.5171
# Combo: ('CCONJ', 'PRON', 'VERB') -> Accuracy: 0.5276
# Combo: ('CCONJ', 'PRON', 'SCONJ') -> Accuracy: 0.5153
# Combo: ('CCONJ', 'PRON', 'ADJ') -> Accuracy: 0.5230
# Combo: ('CCONJ', 'PRON', 'NOUN') -> Accuracy: 0.5248
# Combo: ('CCONJ', 'PRON', 'ADV') -> Accuracy: 0.5208
# Combo: ('CCONJ', 'PRON', 'PROPN') -> Accuracy: 0.5225
# Combo: ('CCONJ', 'PRON', 'ADP') -> Accuracy: 0.5225
# Combo: ('CCONJ', 'VERB', 'SCONJ') -> Accuracy: 0.5195
# Combo: ('CCONJ', 'VERB', 'ADJ') -> Accuracy: 0.5192
# Combo: ('CCONJ', 'VERB', 'NOUN') -> Accuracy: 0.5253
# Combo: ('CCONJ', 'VERB', 'ADV') -> Accuracy: 0.5201
# Combo: ('CCONJ', 'VERB', 'PROPN') -> Accuracy: 0.5259
# Combo: ('CCONJ', 'VERB', 'ADP') -> Accuracy: 0.5214
# Combo: ('CCONJ', 'SCONJ', 'ADJ') -> Accuracy: 0.5124
# Combo: ('CCONJ', 'SCONJ', 'NOUN') -> Accuracy: 0.5220
# Combo: ('CCONJ', 'SCONJ', 'ADV') -> Accuracy: 0.5199
# Combo: ('CCONJ', 'SCONJ', 'PROPN') -> Accuracy: 0.5136
# Combo: ('CCONJ', 'SCONJ', 'ADP') -> Accuracy: 0.5111
# Combo: ('CCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5243
# Combo: ('CCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5219
# Combo: ('CCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5194
# Combo: ('CCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5128
# Combo: ('CCONJ', 'NOUN', 'ADV') -> Accuracy: 0.5220
# Combo: ('CCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5263
# Combo: ('CCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5153
# Combo: ('CCONJ', 'ADV', 'PROPN') -> Accuracy: 0.5241
# Combo: ('CCONJ', 'ADV', 'ADP') -> Accuracy: 0.5194
# Combo: ('CCONJ', 'PROPN', 'ADP') -> Accuracy: 0.5232
# Combo: ('INTJ', 'PRON', 'VERB') -> Accuracy: 0.5334
# Combo: ('INTJ', 'PRON', 'SCONJ') -> Accuracy: 0.5261
# Combo: ('INTJ', 'PRON', 'ADJ') -> Accuracy: 0.5291
# Combo: ('INTJ', 'PRON', 'NOUN') -> Accuracy: 0.5303
# Combo: ('INTJ', 'PRON', 'ADV') -> Accuracy: 0.5223
# Combo: ('INTJ', 'PRON', 'PROPN') -> Accuracy: 0.5247
# Combo: ('INTJ', 'PRON', 'ADP') -> Accuracy: 0.5281
# Combo: ('INTJ', 'VERB', 'SCONJ') -> Accuracy: 0.5268
# Combo: ('INTJ', 'VERB', 'ADJ') -> Accuracy: 0.5271
# Combo: ('INTJ', 'VERB', 'NOUN') -> Accuracy: 0.5296
# Combo: ('INTJ', 'VERB', 'ADV') -> Accuracy: 0.5282
# Combo: ('INTJ', 'VERB', 'PROPN') -> Accuracy: 0.5306
# Combo: ('INTJ', 'VERB', 'ADP') -> Accuracy: 0.5291
# Combo: ('INTJ', 'SCONJ', 'ADJ') -> Accuracy: 0.5172
# Combo: ('INTJ', 'SCONJ', 'NOUN') -> Accuracy: 0.5269
# Combo: ('INTJ', 'SCONJ', 'ADV') -> Accuracy: 0.5255
# Combo: ('INTJ', 'SCONJ', 'PROPN') -> Accuracy: 0.5282
# Combo: ('INTJ', 'SCONJ', 'ADP') -> Accuracy: 0.5174
# Combo: ('INTJ', 'ADJ', 'NOUN') -> Accuracy: 0.5190
# Combo: ('INTJ', 'ADJ', 'ADV') -> Accuracy: 0.5214
# Combo: ('INTJ', 'ADJ', 'PROPN') -> Accuracy: 0.5268
# Combo: ('INTJ', 'ADJ', 'ADP') -> Accuracy: 0.5158
# Combo: ('INTJ', 'NOUN', 'ADV') -> Accuracy: 0.5256
# Combo: ('INTJ', 'NOUN', 'PROPN') -> Accuracy: 0.5249
# Combo: ('INTJ', 'NOUN', 'ADP') -> Accuracy: 0.5154
# Combo: ('INTJ', 'ADV', 'PROPN') -> Accuracy: 0.5239
# Combo: ('INTJ', 'ADV', 'ADP') -> Accuracy: 0.5206
# Combo: ('INTJ', 'PROPN', 'ADP') -> Accuracy: 0.5248
# Combo: ('PRON', 'VERB', 'SCONJ') -> Accuracy: 0.5323
# Combo: ('PRON', 'VERB', 'ADJ') -> Accuracy: 0.5323
# Combo: ('PRON', 'VERB', 'NOUN') -> Accuracy: 0.5317
# Combo: ('PRON', 'VERB', 'ADV') -> Accuracy: 0.5316
# Combo: ('PRON', 'VERB', 'PROPN') -> Accuracy: 0.5294
# Combo: ('PRON', 'VERB', 'ADP') -> Accuracy: 0.5305
# Combo: ('PRON', 'SCONJ', 'ADJ') -> Accuracy: 0.5243
# Combo: ('PRON', 'SCONJ', 'NOUN') -> Accuracy: 0.5256
# Combo: ('PRON', 'SCONJ', 'ADV') -> Accuracy: 0.5137
# Combo: ('PRON', 'SCONJ', 'PROPN') -> Accuracy: 0.5213
# Combo: ('PRON', 'SCONJ', 'ADP') -> Accuracy: 0.5228
# Combo: ('PRON', 'ADJ', 'NOUN') -> Accuracy: 0.5254
# Combo: ('PRON', 'ADJ', 'ADV') -> Accuracy: 0.5241
# Combo: ('PRON', 'ADJ', 'PROPN') -> Accuracy: 0.5238
# Combo: ('PRON', 'ADJ', 'ADP') -> Accuracy: 0.5253
# Combo: ('PRON', 'NOUN', 'ADV') -> Accuracy: 0.5189
# Combo: ('PRON', 'NOUN', 'PROPN') -> Accuracy: 0.5270
# Combo: ('PRON', 'NOUN', 'ADP') -> Accuracy: 0.5287
# Combo: ('PRON', 'ADV', 'PROPN') -> Accuracy: 0.5232
# Combo: ('PRON', 'ADV', 'ADP') -> Accuracy: 0.5240
# Combo: ('PRON', 'PROPN', 'ADP') -> Accuracy: 0.5234
# Combo: ('VERB', 'SCONJ', 'ADJ') -> Accuracy: 0.5193
# Combo: ('VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5276
# Combo: ('VERB', 'SCONJ', 'ADV') -> Accuracy: 0.5213
# Combo: ('VERB', 'SCONJ', 'PROPN') -> Accuracy: 0.5276
# Combo: ('VERB', 'SCONJ', 'ADP') -> Accuracy: 0.5218
# Combo: ('VERB', 'ADJ', 'NOUN') -> Accuracy: 0.5243
# Combo: ('VERB', 'ADJ', 'ADV') -> Accuracy: 0.5224
# Combo: ('VERB', 'ADJ', 'PROPN') -> Accuracy: 0.5264
# Combo: ('VERB', 'ADJ', 'ADP') -> Accuracy: 0.5223
# Combo: ('VERB', 'NOUN', 'ADV') -> Accuracy: 0.5229
# Combo: ('VERB', 'NOUN', 'PROPN') -> Accuracy: 0.5302
# Combo: ('VERB', 'NOUN', 'ADP') -> Accuracy: 0.5234
# Combo: ('VERB', 'ADV', 'PROPN') -> Accuracy: 0.5324
# Combo: ('VERB', 'ADV', 'ADP') -> Accuracy: 0.5250
# Combo: ('VERB', 'PROPN', 'ADP') -> Accuracy: 0.5246
# Combo: ('SCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5222
# Combo: ('SCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5209
# Combo: ('SCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5164
# Combo: ('SCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5132
# Combo: ('SCONJ', 'NOUN', 'ADV') -> Accuracy: 0.5195
# Combo: ('SCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5241
# Combo: ('SCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5157
# Combo: ('SCONJ', 'ADV', 'PROPN') -> Accuracy: 0.5252
# Combo: ('SCONJ', 'ADV', 'ADP') -> Accuracy: 0.5196
# Combo: ('SCONJ', 'PROPN', 'ADP') -> Accuracy: 0.5226
# Combo: ('ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5194
# Combo: ('ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5203
# Combo: ('ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5149
# Combo: ('ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5237
# Combo: ('ADJ', 'ADV', 'ADP') -> Accuracy: 0.5191
# Combo: ('ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5232
# Combo: ('NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5215
# Combo: ('NOUN', 'ADV', 'ADP') -> Accuracy: 0.5187
# Combo: ('NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5174
# Combo: ('ADV', 'PROPN', 'ADP') -> Accuracy: 0.5198
#
# --- Subset Size: 4 ---
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON') -> Accuracy: 0.5282
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB') -> Accuracy: 0.5328
# Combo: ('AUX', 'CCONJ', 'INTJ', 'SCONJ') -> Accuracy: 0.5304
# Combo: ('AUX', 'CCONJ', 'INTJ', 'ADJ') -> Accuracy: 0.5312
# Combo: ('AUX', 'CCONJ', 'INTJ', 'NOUN') -> Accuracy: 0.5342
# Combo: ('AUX', 'CCONJ', 'INTJ', 'ADV') -> Accuracy: 0.5329
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PROPN') -> Accuracy: 0.5341
# Combo: ('AUX', 'CCONJ', 'INTJ', 'ADP') -> Accuracy: 0.5302
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB') -> Accuracy: 0.5348
# Combo: ('AUX', 'CCONJ', 'PRON', 'SCONJ') -> Accuracy: 0.5248
# Combo: ('AUX', 'CCONJ', 'PRON', 'ADJ') -> Accuracy: 0.5280
# Combo: ('AUX', 'CCONJ', 'PRON', 'NOUN') -> Accuracy: 0.5340
# Combo: ('AUX', 'CCONJ', 'PRON', 'ADV') -> Accuracy: 0.5256
# Combo: ('AUX', 'CCONJ', 'PRON', 'PROPN') -> Accuracy: 0.5299
# Combo: ('AUX', 'CCONJ', 'PRON', 'ADP') -> Accuracy: 0.5252
# Combo: ('AUX', 'CCONJ', 'VERB', 'SCONJ') -> Accuracy: 0.5304
# Combo: ('AUX', 'CCONJ', 'VERB', 'ADJ') -> Accuracy: 0.5290
# Combo: ('AUX', 'CCONJ', 'VERB', 'NOUN') -> Accuracy: 0.5324
# Combo: ('AUX', 'CCONJ', 'VERB', 'ADV') -> Accuracy: 0.5314
# Combo: ('AUX', 'CCONJ', 'VERB', 'PROPN') -> Accuracy: 0.5302
# Combo: ('AUX', 'CCONJ', 'VERB', 'ADP') -> Accuracy: 0.5216
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'ADJ') -> Accuracy: 0.5259
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'NOUN') -> Accuracy: 0.5322
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'ADV') -> Accuracy: 0.5302
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'PROPN') -> Accuracy: 0.5313
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'ADP') -> Accuracy: 0.5236
# Combo: ('AUX', 'CCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5229
# Combo: ('AUX', 'CCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5262
# Combo: ('AUX', 'CCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5265
# Combo: ('AUX', 'CCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5252
# Combo: ('AUX', 'CCONJ', 'NOUN', 'ADV') -> Accuracy: 0.5252
# Combo: ('AUX', 'CCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5339
# Combo: ('AUX', 'CCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5304
# Combo: ('AUX', 'CCONJ', 'ADV', 'PROPN') -> Accuracy: 0.5334
# Combo: ('AUX', 'CCONJ', 'ADV', 'ADP') -> Accuracy: 0.5278
# Combo: ('AUX', 'CCONJ', 'PROPN', 'ADP') -> Accuracy: 0.5261
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB') -> Accuracy: 0.5420
# Combo: ('AUX', 'INTJ', 'PRON', 'SCONJ') -> Accuracy: 0.5279
# Combo: ('AUX', 'INTJ', 'PRON', 'ADJ') -> Accuracy: 0.5327
# Combo: ('AUX', 'INTJ', 'PRON', 'NOUN') -> Accuracy: 0.5328
# Combo: ('AUX', 'INTJ', 'PRON', 'ADV') -> Accuracy: 0.5314
# Combo: ('AUX', 'INTJ', 'PRON', 'PROPN') -> Accuracy: 0.5336
# Combo: ('AUX', 'INTJ', 'PRON', 'ADP') -> Accuracy: 0.5320
# Combo: ('AUX', 'INTJ', 'VERB', 'SCONJ') -> Accuracy: 0.5320
# Combo: ('AUX', 'INTJ', 'VERB', 'ADJ') -> Accuracy: 0.5319
# Combo: ('AUX', 'INTJ', 'VERB', 'NOUN') -> Accuracy: 0.5390
# Combo: ('AUX', 'INTJ', 'VERB', 'ADV') -> Accuracy: 0.5362
# Combo: ('AUX', 'INTJ', 'VERB', 'PROPN') -> Accuracy: 0.5322
# Combo: ('AUX', 'INTJ', 'VERB', 'ADP') -> Accuracy: 0.5252
# Combo: ('AUX', 'INTJ', 'SCONJ', 'ADJ') -> Accuracy: 0.5302
# Combo: ('AUX', 'INTJ', 'SCONJ', 'NOUN') -> Accuracy: 0.5337
# Combo: ('AUX', 'INTJ', 'SCONJ', 'ADV') -> Accuracy: 0.5341
# Combo: ('AUX', 'INTJ', 'SCONJ', 'PROPN') -> Accuracy: 0.5349
# Combo: ('AUX', 'INTJ', 'SCONJ', 'ADP') -> Accuracy: 0.5284
# Combo: ('AUX', 'INTJ', 'ADJ', 'NOUN') -> Accuracy: 0.5340
# Combo: ('AUX', 'INTJ', 'ADJ', 'ADV') -> Accuracy: 0.5369
# Combo: ('AUX', 'INTJ', 'ADJ', 'PROPN') -> Accuracy: 0.5314
# Combo: ('AUX', 'INTJ', 'ADJ', 'ADP') -> Accuracy: 0.5243
# Combo: ('AUX', 'INTJ', 'NOUN', 'ADV') -> Accuracy: 0.5302
# Combo: ('AUX', 'INTJ', 'NOUN', 'PROPN') -> Accuracy: 0.5370
# Combo: ('AUX', 'INTJ', 'NOUN', 'ADP') -> Accuracy: 0.5347
# Combo: ('AUX', 'INTJ', 'ADV', 'PROPN') -> Accuracy: 0.5405
# Combo: ('AUX', 'INTJ', 'ADV', 'ADP') -> Accuracy: 0.5320
# Combo: ('AUX', 'INTJ', 'PROPN', 'ADP') -> Accuracy: 0.5361
# Combo: ('AUX', 'PRON', 'VERB', 'SCONJ') -> Accuracy: 0.5399
# Combo: ('AUX', 'PRON', 'VERB', 'ADJ') -> Accuracy: 0.5354
# Combo: ('AUX', 'PRON', 'VERB', 'NOUN') -> Accuracy: 0.5414
# Combo: ('AUX', 'PRON', 'VERB', 'ADV') -> Accuracy: 0.5406
# Combo: ('AUX', 'PRON', 'VERB', 'PROPN') -> Accuracy: 0.5379
# Combo: ('AUX', 'PRON', 'VERB', 'ADP') -> Accuracy: 0.5355
# Combo: ('AUX', 'PRON', 'SCONJ', 'ADJ') -> Accuracy: 0.5264
# Combo: ('AUX', 'PRON', 'SCONJ', 'NOUN') -> Accuracy: 0.5291
# Combo: ('AUX', 'PRON', 'SCONJ', 'ADV') -> Accuracy: 0.5278
# Combo: ('AUX', 'PRON', 'SCONJ', 'PROPN') -> Accuracy: 0.5287
# Combo: ('AUX', 'PRON', 'SCONJ', 'ADP') -> Accuracy: 0.5231
# Combo: ('AUX', 'PRON', 'ADJ', 'NOUN') -> Accuracy: 0.5294
# Combo: ('AUX', 'PRON', 'ADJ', 'ADV') -> Accuracy: 0.5262
# Combo: ('AUX', 'PRON', 'ADJ', 'PROPN') -> Accuracy: 0.5335
# Combo: ('AUX', 'PRON', 'ADJ', 'ADP') -> Accuracy: 0.5314
# Combo: ('AUX', 'PRON', 'NOUN', 'ADV') -> Accuracy: 0.5282
# Combo: ('AUX', 'PRON', 'NOUN', 'PROPN') -> Accuracy: 0.5322
# Combo: ('AUX', 'PRON', 'NOUN', 'ADP') -> Accuracy: 0.5302
# Combo: ('AUX', 'PRON', 'ADV', 'PROPN') -> Accuracy: 0.5295
# Combo: ('AUX', 'PRON', 'ADV', 'ADP') -> Accuracy: 0.5262
# Combo: ('AUX', 'PRON', 'PROPN', 'ADP') -> Accuracy: 0.5291
# Combo: ('AUX', 'VERB', 'SCONJ', 'ADJ') -> Accuracy: 0.5280
# Combo: ('AUX', 'VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5315
# Combo: ('AUX', 'VERB', 'SCONJ', 'ADV') -> Accuracy: 0.5324
# Combo: ('AUX', 'VERB', 'SCONJ', 'PROPN') -> Accuracy: 0.5321
# Combo: ('AUX', 'VERB', 'SCONJ', 'ADP') -> Accuracy: 0.5214
# Combo: ('AUX', 'VERB', 'ADJ', 'NOUN') -> Accuracy: 0.5253
# Combo: ('AUX', 'VERB', 'ADJ', 'ADV') -> Accuracy: 0.5265
# Combo: ('AUX', 'VERB', 'ADJ', 'PROPN') -> Accuracy: 0.5256
# Combo: ('AUX', 'VERB', 'ADJ', 'ADP') -> Accuracy: 0.5234
# Combo: ('AUX', 'VERB', 'NOUN', 'ADV') -> Accuracy: 0.5343
# Combo: ('AUX', 'VERB', 'NOUN', 'PROPN') -> Accuracy: 0.5345
# Combo: ('AUX', 'VERB', 'NOUN', 'ADP') -> Accuracy: 0.5274
# Combo: ('AUX', 'VERB', 'ADV', 'PROPN') -> Accuracy: 0.5326
# Combo: ('AUX', 'VERB', 'ADV', 'ADP') -> Accuracy: 0.5282
# Combo: ('AUX', 'VERB', 'PROPN', 'ADP') -> Accuracy: 0.5258
# Combo: ('AUX', 'SCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5252
# Combo: ('AUX', 'SCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5300
# Combo: ('AUX', 'SCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5284
# Combo: ('AUX', 'SCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5192
# Combo: ('AUX', 'SCONJ', 'NOUN', 'ADV') -> Accuracy: 0.5263
# Combo: ('AUX', 'SCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5338
# Combo: ('AUX', 'SCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5318
# Combo: ('AUX', 'SCONJ', 'ADV', 'PROPN') -> Accuracy: 0.5344
# Combo: ('AUX', 'SCONJ', 'ADV', 'ADP') -> Accuracy: 0.5279
# Combo: ('AUX', 'SCONJ', 'PROPN', 'ADP') -> Accuracy: 0.5250
# Combo: ('AUX', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5234
# Combo: ('AUX', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5311
# Combo: ('AUX', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5252
# Combo: ('AUX', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5339
# Combo: ('AUX', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5271
# Combo: ('AUX', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5276
# Combo: ('AUX', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5315
# Combo: ('AUX', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5282
# Combo: ('AUX', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5314
# Combo: ('AUX', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5362
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB') -> Accuracy: 0.5306
# Combo: ('CCONJ', 'INTJ', 'PRON', 'SCONJ') -> Accuracy: 0.5226
# Combo: ('CCONJ', 'INTJ', 'PRON', 'ADJ') -> Accuracy: 0.5296
# Combo: ('CCONJ', 'INTJ', 'PRON', 'NOUN') -> Accuracy: 0.5285
# Combo: ('CCONJ', 'INTJ', 'PRON', 'ADV') -> Accuracy: 0.5248
# Combo: ('CCONJ', 'INTJ', 'PRON', 'PROPN') -> Accuracy: 0.5224
# Combo: ('CCONJ', 'INTJ', 'PRON', 'ADP') -> Accuracy: 0.5263
# Combo: ('CCONJ', 'INTJ', 'VERB', 'SCONJ') -> Accuracy: 0.5263
# Combo: ('CCONJ', 'INTJ', 'VERB', 'ADJ') -> Accuracy: 0.5226
# Combo: ('CCONJ', 'INTJ', 'VERB', 'NOUN') -> Accuracy: 0.5278
# Combo: ('CCONJ', 'INTJ', 'VERB', 'ADV') -> Accuracy: 0.5244
# Combo: ('CCONJ', 'INTJ', 'VERB', 'PROPN') -> Accuracy: 0.5305
# Combo: ('CCONJ', 'INTJ', 'VERB', 'ADP') -> Accuracy: 0.5267
# Combo: ('CCONJ', 'INTJ', 'SCONJ', 'ADJ') -> Accuracy: 0.5198
# Combo: ('CCONJ', 'INTJ', 'SCONJ', 'NOUN') -> Accuracy: 0.5274
# Combo: ('CCONJ', 'INTJ', 'SCONJ', 'ADV') -> Accuracy: 0.5225
# Combo: ('CCONJ', 'INTJ', 'SCONJ', 'PROPN') -> Accuracy: 0.5282
# Combo: ('CCONJ', 'INTJ', 'SCONJ', 'ADP') -> Accuracy: 0.5205
# Combo: ('CCONJ', 'INTJ', 'ADJ', 'NOUN') -> Accuracy: 0.5227
# Combo: ('CCONJ', 'INTJ', 'ADJ', 'ADV') -> Accuracy: 0.5244
# Combo: ('CCONJ', 'INTJ', 'ADJ', 'PROPN') -> Accuracy: 0.5301
# Combo: ('CCONJ', 'INTJ', 'ADJ', 'ADP') -> Accuracy: 0.5164
# Combo: ('CCONJ', 'INTJ', 'NOUN', 'ADV') -> Accuracy: 0.5229
# Combo: ('CCONJ', 'INTJ', 'NOUN', 'PROPN') -> Accuracy: 0.5272
# Combo: ('CCONJ', 'INTJ', 'NOUN', 'ADP') -> Accuracy: 0.5208
# Combo: ('CCONJ', 'INTJ', 'ADV', 'PROPN') -> Accuracy: 0.5245
# Combo: ('CCONJ', 'INTJ', 'ADV', 'ADP') -> Accuracy: 0.5212
# Combo: ('CCONJ', 'INTJ', 'PROPN', 'ADP') -> Accuracy: 0.5279
# Combo: ('CCONJ', 'PRON', 'VERB', 'SCONJ') -> Accuracy: 0.5308
# Combo: ('CCONJ', 'PRON', 'VERB', 'ADJ') -> Accuracy: 0.5309
# Combo: ('CCONJ', 'PRON', 'VERB', 'NOUN') -> Accuracy: 0.5322
# Combo: ('CCONJ', 'PRON', 'VERB', 'ADV') -> Accuracy: 0.5328
# Combo: ('CCONJ', 'PRON', 'VERB', 'PROPN') -> Accuracy: 0.5292
# Combo: ('CCONJ', 'PRON', 'VERB', 'ADP') -> Accuracy: 0.5285
# Combo: ('CCONJ', 'PRON', 'SCONJ', 'ADJ') -> Accuracy: 0.5242
# Combo: ('CCONJ', 'PRON', 'SCONJ', 'NOUN') -> Accuracy: 0.5293
# Combo: ('CCONJ', 'PRON', 'SCONJ', 'ADV') -> Accuracy: 0.5198
# Combo: ('CCONJ', 'PRON', 'SCONJ', 'PROPN') -> Accuracy: 0.5238
# Combo: ('CCONJ', 'PRON', 'SCONJ', 'ADP') -> Accuracy: 0.5235
# Combo: ('CCONJ', 'PRON', 'ADJ', 'NOUN') -> Accuracy: 0.5266
# Combo: ('CCONJ', 'PRON', 'ADJ', 'ADV') -> Accuracy: 0.5258
# Combo: ('CCONJ', 'PRON', 'ADJ', 'PROPN') -> Accuracy: 0.5236
# Combo: ('CCONJ', 'PRON', 'ADJ', 'ADP') -> Accuracy: 0.5281
# Combo: ('CCONJ', 'PRON', 'NOUN', 'ADV') -> Accuracy: 0.5198
# Combo: ('CCONJ', 'PRON', 'NOUN', 'PROPN') -> Accuracy: 0.5278
# Combo: ('CCONJ', 'PRON', 'NOUN', 'ADP') -> Accuracy: 0.5282
# Combo: ('CCONJ', 'PRON', 'ADV', 'PROPN') -> Accuracy: 0.5236
# Combo: ('CCONJ', 'PRON', 'ADV', 'ADP') -> Accuracy: 0.5240
# Combo: ('CCONJ', 'PRON', 'PROPN', 'ADP') -> Accuracy: 0.5257
# Combo: ('CCONJ', 'VERB', 'SCONJ', 'ADJ') -> Accuracy: 0.5202
# Combo: ('CCONJ', 'VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5276
# Combo: ('CCONJ', 'VERB', 'SCONJ', 'ADV') -> Accuracy: 0.5206
# Combo: ('CCONJ', 'VERB', 'SCONJ', 'PROPN') -> Accuracy: 0.5265
# Combo: ('CCONJ', 'VERB', 'SCONJ', 'ADP') -> Accuracy: 0.5212
# Combo: ('CCONJ', 'VERB', 'ADJ', 'NOUN') -> Accuracy: 0.5219
# Combo: ('CCONJ', 'VERB', 'ADJ', 'ADV') -> Accuracy: 0.5232
# Combo: ('CCONJ', 'VERB', 'ADJ', 'PROPN') -> Accuracy: 0.5295
# Combo: ('CCONJ', 'VERB', 'ADJ', 'ADP') -> Accuracy: 0.5206
# Combo: ('CCONJ', 'VERB', 'NOUN', 'ADV') -> Accuracy: 0.5245
# Combo: ('CCONJ', 'VERB', 'NOUN', 'PROPN') -> Accuracy: 0.5307
# Combo: ('CCONJ', 'VERB', 'NOUN', 'ADP') -> Accuracy: 0.5235
# Combo: ('CCONJ', 'VERB', 'ADV', 'PROPN') -> Accuracy: 0.5293
# Combo: ('CCONJ', 'VERB', 'ADV', 'ADP') -> Accuracy: 0.5230
# Combo: ('CCONJ', 'VERB', 'PROPN', 'ADP') -> Accuracy: 0.5260
# Combo: ('CCONJ', 'SCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5231
# Combo: ('CCONJ', 'SCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5236
# Combo: ('CCONJ', 'SCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5196
# Combo: ('CCONJ', 'SCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5182
# Combo: ('CCONJ', 'SCONJ', 'NOUN', 'ADV') -> Accuracy: 0.5212
# Combo: ('CCONJ', 'SCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5292
# Combo: ('CCONJ', 'SCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5178
# Combo: ('CCONJ', 'SCONJ', 'ADV', 'PROPN') -> Accuracy: 0.5250
# Combo: ('CCONJ', 'SCONJ', 'ADV', 'ADP') -> Accuracy: 0.5198
# Combo: ('CCONJ', 'SCONJ', 'PROPN', 'ADP') -> Accuracy: 0.5222
# Combo: ('CCONJ', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5200
# Combo: ('CCONJ', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5233
# Combo: ('CCONJ', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5207
# Combo: ('CCONJ', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5265
# Combo: ('CCONJ', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5202
# Combo: ('CCONJ', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5214
# Combo: ('CCONJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5232
# Combo: ('CCONJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5163
# Combo: ('CCONJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5211
# Combo: ('CCONJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5220
# Combo: ('INTJ', 'PRON', 'VERB', 'SCONJ') -> Accuracy: 0.5359
# Combo: ('INTJ', 'PRON', 'VERB', 'ADJ') -> Accuracy: 0.5342
# Combo: ('INTJ', 'PRON', 'VERB', 'NOUN') -> Accuracy: 0.5384
# Combo: ('INTJ', 'PRON', 'VERB', 'ADV') -> Accuracy: 0.5367
# Combo: ('INTJ', 'PRON', 'VERB', 'PROPN') -> Accuracy: 0.5310
# Combo: ('INTJ', 'PRON', 'VERB', 'ADP') -> Accuracy: 0.5326
# Combo: ('INTJ', 'PRON', 'SCONJ', 'ADJ') -> Accuracy: 0.5308
# Combo: ('INTJ', 'PRON', 'SCONJ', 'NOUN') -> Accuracy: 0.5312
# Combo: ('INTJ', 'PRON', 'SCONJ', 'ADV') -> Accuracy: 0.5256
# Combo: ('INTJ', 'PRON', 'SCONJ', 'PROPN') -> Accuracy: 0.5240
# Combo: ('INTJ', 'PRON', 'SCONJ', 'ADP') -> Accuracy: 0.5269
# Combo: ('INTJ', 'PRON', 'ADJ', 'NOUN') -> Accuracy: 0.5351
# Combo: ('INTJ', 'PRON', 'ADJ', 'ADV') -> Accuracy: 0.5293
# Combo: ('INTJ', 'PRON', 'ADJ', 'PROPN') -> Accuracy: 0.5274
# Combo: ('INTJ', 'PRON', 'ADJ', 'ADP') -> Accuracy: 0.5285
# Combo: ('INTJ', 'PRON', 'NOUN', 'ADV') -> Accuracy: 0.5244
# Combo: ('INTJ', 'PRON', 'NOUN', 'PROPN') -> Accuracy: 0.5330
# Combo: ('INTJ', 'PRON', 'NOUN', 'ADP') -> Accuracy: 0.5315
# Combo: ('INTJ', 'PRON', 'ADV', 'PROPN') -> Accuracy: 0.5241
# Combo: ('INTJ', 'PRON', 'ADV', 'ADP') -> Accuracy: 0.5274
# Combo: ('INTJ', 'PRON', 'PROPN', 'ADP') -> Accuracy: 0.5264
# Combo: ('INTJ', 'VERB', 'SCONJ', 'ADJ') -> Accuracy: 0.5239
# Combo: ('INTJ', 'VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5299
# Combo: ('INTJ', 'VERB', 'SCONJ', 'ADV') -> Accuracy: 0.5291
# Combo: ('INTJ', 'VERB', 'SCONJ', 'PROPN') -> Accuracy: 0.5323
# Combo: ('INTJ', 'VERB', 'SCONJ', 'ADP') -> Accuracy: 0.5268
# Combo: ('INTJ', 'VERB', 'ADJ', 'NOUN') -> Accuracy: 0.5273
# Combo: ('INTJ', 'VERB', 'ADJ', 'ADV') -> Accuracy: 0.5269
# Combo: ('INTJ', 'VERB', 'ADJ', 'PROPN') -> Accuracy: 0.5332
# Combo: ('INTJ', 'VERB', 'ADJ', 'ADP') -> Accuracy: 0.5285
# Combo: ('INTJ', 'VERB', 'NOUN', 'ADV') -> Accuracy: 0.5260
# Combo: ('INTJ', 'VERB', 'NOUN', 'PROPN') -> Accuracy: 0.5359
# Combo: ('INTJ', 'VERB', 'NOUN', 'ADP') -> Accuracy: 0.5305
# Combo: ('INTJ', 'VERB', 'ADV', 'PROPN') -> Accuracy: 0.5326
# Combo: ('INTJ', 'VERB', 'ADV', 'ADP') -> Accuracy: 0.5324
# Combo: ('INTJ', 'VERB', 'PROPN', 'ADP') -> Accuracy: 0.5269
# Combo: ('INTJ', 'SCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5243
# Combo: ('INTJ', 'SCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5235
# Combo: ('INTJ', 'SCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5285
# Combo: ('INTJ', 'SCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5170
# Combo: ('INTJ', 'SCONJ', 'NOUN', 'ADV') -> Accuracy: 0.5256
# Combo: ('INTJ', 'SCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5256
# Combo: ('INTJ', 'SCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5188
# Combo: ('INTJ', 'SCONJ', 'ADV', 'PROPN') -> Accuracy: 0.5263
# Combo: ('INTJ', 'SCONJ', 'ADV', 'ADP') -> Accuracy: 0.5224
# Combo: ('INTJ', 'SCONJ', 'PROPN', 'ADP') -> Accuracy: 0.5259
# Combo: ('INTJ', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5218
# Combo: ('INTJ', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5253
# Combo: ('INTJ', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5206
# Combo: ('INTJ', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5275
# Combo: ('INTJ', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5240
# Combo: ('INTJ', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5296
# Combo: ('INTJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5218
# Combo: ('INTJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5198
# Combo: ('INTJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5193
# Combo: ('INTJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5279
# Combo: ('PRON', 'VERB', 'SCONJ', 'ADJ') -> Accuracy: 0.5322
# Combo: ('PRON', 'VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5327
# Combo: ('PRON', 'VERB', 'SCONJ', 'ADV') -> Accuracy: 0.5345
# Combo: ('PRON', 'VERB', 'SCONJ', 'PROPN') -> Accuracy: 0.5321
# Combo: ('PRON', 'VERB', 'SCONJ', 'ADP') -> Accuracy: 0.5301
# Combo: ('PRON', 'VERB', 'ADJ', 'NOUN') -> Accuracy: 0.5315
# Combo: ('PRON', 'VERB', 'ADJ', 'ADV') -> Accuracy: 0.5337
# Combo: ('PRON', 'VERB', 'ADJ', 'PROPN') -> Accuracy: 0.5272
# Combo: ('PRON', 'VERB', 'ADJ', 'ADP') -> Accuracy: 0.5244
# Combo: ('PRON', 'VERB', 'NOUN', 'ADV') -> Accuracy: 0.5348
# Combo: ('PRON', 'VERB', 'NOUN', 'PROPN') -> Accuracy: 0.5349
# Combo: ('PRON', 'VERB', 'NOUN', 'ADP') -> Accuracy: 0.5258
# Combo: ('PRON', 'VERB', 'ADV', 'PROPN') -> Accuracy: 0.5345
# Combo: ('PRON', 'VERB', 'ADV', 'ADP') -> Accuracy: 0.5329
# Combo: ('PRON', 'VERB', 'PROPN', 'ADP') -> Accuracy: 0.5243
# Combo: ('PRON', 'SCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5236
# Combo: ('PRON', 'SCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5242
# Combo: ('PRON', 'SCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5249
# Combo: ('PRON', 'SCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5264
# Combo: ('PRON', 'SCONJ', 'NOUN', 'ADV') -> Accuracy: 0.5240
# Combo: ('PRON', 'SCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5305
# Combo: ('PRON', 'SCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5285
# Combo: ('PRON', 'SCONJ', 'ADV', 'PROPN') -> Accuracy: 0.5240
# Combo: ('PRON', 'SCONJ', 'ADV', 'ADP') -> Accuracy: 0.5281
# Combo: ('PRON', 'SCONJ', 'PROPN', 'ADP') -> Accuracy: 0.5242
# Combo: ('PRON', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5292
# Combo: ('PRON', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5326
# Combo: ('PRON', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5291
# Combo: ('PRON', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5249
# Combo: ('PRON', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5280
# Combo: ('PRON', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5254
# Combo: ('PRON', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5310
# Combo: ('PRON', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5273
# Combo: ('PRON', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5282
# Combo: ('PRON', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5268
# Combo: ('VERB', 'SCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5262
# Combo: ('VERB', 'SCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5230
# Combo: ('VERB', 'SCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5276
# Combo: ('VERB', 'SCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5237
# Combo: ('VERB', 'SCONJ', 'NOUN', 'ADV') -> Accuracy: 0.5269
# Combo: ('VERB', 'SCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5281
# Combo: ('VERB', 'SCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5259
# Combo: ('VERB', 'SCONJ', 'ADV', 'PROPN') -> Accuracy: 0.5295
# Combo: ('VERB', 'SCONJ', 'ADV', 'ADP') -> Accuracy: 0.5236
# Combo: ('VERB', 'SCONJ', 'PROPN', 'ADP') -> Accuracy: 0.5246
# Combo: ('VERB', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5183
# Combo: ('VERB', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5245
# Combo: ('VERB', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5207
# Combo: ('VERB', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5274
# Combo: ('VERB', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5264
# Combo: ('VERB', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5248
# Combo: ('VERB', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5264
# Combo: ('VERB', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5261
# Combo: ('VERB', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5291
# Combo: ('VERB', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5330
# Combo: ('SCONJ', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5184
# Combo: ('SCONJ', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5193
# Combo: ('SCONJ', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5180
# Combo: ('SCONJ', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5193
# Combo: ('SCONJ', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5209
# Combo: ('SCONJ', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5184
# Combo: ('SCONJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5223
# Combo: ('SCONJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5166
# Combo: ('SCONJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5191
# Combo: ('SCONJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5212
# Combo: ('ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5234
# Combo: ('ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5204
# Combo: ('ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5200
# Combo: ('ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5269
# Combo: ('NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5235
#
# --- Subset Size: 5 ---
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB') -> Accuracy: 0.5403
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'SCONJ') -> Accuracy: 0.5280
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'ADJ') -> Accuracy: 0.5303
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'NOUN') -> Accuracy: 0.5346
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'ADV') -> Accuracy: 0.5278
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'PROPN') -> Accuracy: 0.5290
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'ADP') -> Accuracy: 0.5286
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'SCONJ') -> Accuracy: 0.5314
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'ADJ') -> Accuracy: 0.5313
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'NOUN') -> Accuracy: 0.5379
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'ADV') -> Accuracy: 0.5361
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'PROPN') -> Accuracy: 0.5311
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'ADP') -> Accuracy: 0.5242
# Combo: ('AUX', 'CCONJ', 'INTJ', 'SCONJ', 'ADJ') -> Accuracy: 0.5307
# Combo: ('AUX', 'CCONJ', 'INTJ', 'SCONJ', 'NOUN') -> Accuracy: 0.5350
# Combo: ('AUX', 'CCONJ', 'INTJ', 'SCONJ', 'ADV') -> Accuracy: 0.5303
# Combo: ('AUX', 'CCONJ', 'INTJ', 'SCONJ', 'PROPN') -> Accuracy: 0.5336
# Combo: ('AUX', 'CCONJ', 'INTJ', 'SCONJ', 'ADP') -> Accuracy: 0.5239
# Combo: ('AUX', 'CCONJ', 'INTJ', 'ADJ', 'NOUN') -> Accuracy: 0.5308
# Combo: ('AUX', 'CCONJ', 'INTJ', 'ADJ', 'ADV') -> Accuracy: 0.5296
# Combo: ('AUX', 'CCONJ', 'INTJ', 'ADJ', 'PROPN') -> Accuracy: 0.5302
# Combo: ('AUX', 'CCONJ', 'INTJ', 'ADJ', 'ADP') -> Accuracy: 0.5236
# Combo: ('AUX', 'CCONJ', 'INTJ', 'NOUN', 'ADV') -> Accuracy: 0.5295
# Combo: ('AUX', 'CCONJ', 'INTJ', 'NOUN', 'PROPN') -> Accuracy: 0.5334
# Combo: ('AUX', 'CCONJ', 'INTJ', 'NOUN', 'ADP') -> Accuracy: 0.5335
# Combo: ('AUX', 'CCONJ', 'INTJ', 'ADV', 'PROPN') -> Accuracy: 0.5365
# Combo: ('AUX', 'CCONJ', 'INTJ', 'ADV', 'ADP') -> Accuracy: 0.5310
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PROPN', 'ADP') -> Accuracy: 0.5271
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'SCONJ') -> Accuracy: 0.5393
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'ADJ') -> Accuracy: 0.5373
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'NOUN') -> Accuracy: 0.5413
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'ADV') -> Accuracy: 0.5397
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'PROPN') -> Accuracy: 0.5363
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'ADP') -> Accuracy: 0.5346
# Combo: ('AUX', 'CCONJ', 'PRON', 'SCONJ', 'ADJ') -> Accuracy: 0.5274
# Combo: ('AUX', 'CCONJ', 'PRON', 'SCONJ', 'NOUN') -> Accuracy: 0.5305
# Combo: ('AUX', 'CCONJ', 'PRON', 'SCONJ', 'ADV') -> Accuracy: 0.5266
# Combo: ('AUX', 'CCONJ', 'PRON', 'SCONJ', 'PROPN') -> Accuracy: 0.5279
# Combo: ('AUX', 'CCONJ', 'PRON', 'SCONJ', 'ADP') -> Accuracy: 0.5262
# Combo: ('AUX', 'CCONJ', 'PRON', 'ADJ', 'NOUN') -> Accuracy: 0.5312
# Combo: ('AUX', 'CCONJ', 'PRON', 'ADJ', 'ADV') -> Accuracy: 0.5280
# Combo: ('AUX', 'CCONJ', 'PRON', 'ADJ', 'PROPN') -> Accuracy: 0.5283
# Combo: ('AUX', 'CCONJ', 'PRON', 'ADJ', 'ADP') -> Accuracy: 0.5255
# Combo: ('AUX', 'CCONJ', 'PRON', 'NOUN', 'ADV') -> Accuracy: 0.5266
# Combo: ('AUX', 'CCONJ', 'PRON', 'NOUN', 'PROPN') -> Accuracy: 0.5353
# Combo: ('AUX', 'CCONJ', 'PRON', 'NOUN', 'ADP') -> Accuracy: 0.5273
# Combo: ('AUX', 'CCONJ', 'PRON', 'ADV', 'PROPN') -> Accuracy: 0.5250
# Combo: ('AUX', 'CCONJ', 'PRON', 'ADV', 'ADP') -> Accuracy: 0.5229
# Combo: ('AUX', 'CCONJ', 'PRON', 'PROPN', 'ADP') -> Accuracy: 0.5245
# Combo: ('AUX', 'CCONJ', 'VERB', 'SCONJ', 'ADJ') -> Accuracy: 0.5284
# Combo: ('AUX', 'CCONJ', 'VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5338
# Combo: ('AUX', 'CCONJ', 'VERB', 'SCONJ', 'ADV') -> Accuracy: 0.5304
# Combo: ('AUX', 'CCONJ', 'VERB', 'SCONJ', 'PROPN') -> Accuracy: 0.5309
# Combo: ('AUX', 'CCONJ', 'VERB', 'SCONJ', 'ADP') -> Accuracy: 0.5223
# Combo: ('AUX', 'CCONJ', 'VERB', 'ADJ', 'NOUN') -> Accuracy: 0.5271
# Combo: ('AUX', 'CCONJ', 'VERB', 'ADJ', 'ADV') -> Accuracy: 0.5298
# Combo: ('AUX', 'CCONJ', 'VERB', 'ADJ', 'PROPN') -> Accuracy: 0.5284
# Combo: ('AUX', 'CCONJ', 'VERB', 'ADJ', 'ADP') -> Accuracy: 0.5208
# Combo: ('AUX', 'CCONJ', 'VERB', 'NOUN', 'ADV') -> Accuracy: 0.5341
# Combo: ('AUX', 'CCONJ', 'VERB', 'NOUN', 'PROPN') -> Accuracy: 0.5328
# Combo: ('AUX', 'CCONJ', 'VERB', 'NOUN', 'ADP') -> Accuracy: 0.5323
# Combo: ('AUX', 'CCONJ', 'VERB', 'ADV', 'PROPN') -> Accuracy: 0.5344
# Combo: ('AUX', 'CCONJ', 'VERB', 'ADV', 'ADP') -> Accuracy: 0.5275
# Combo: ('AUX', 'CCONJ', 'VERB', 'PROPN', 'ADP') -> Accuracy: 0.5261
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5241
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5295
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5273
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5229
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'NOUN', 'ADV') -> Accuracy: 0.5289
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5331
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5289
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'ADV', 'PROPN') -> Accuracy: 0.5321
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'ADV', 'ADP') -> Accuracy: 0.5265
# Combo: ('AUX', 'CCONJ', 'SCONJ', 'PROPN', 'ADP') -> Accuracy: 0.5251
# Combo: ('AUX', 'CCONJ', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5256
# Combo: ('AUX', 'CCONJ', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5293
# Combo: ('AUX', 'CCONJ', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5283
# Combo: ('AUX', 'CCONJ', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5310
# Combo: ('AUX', 'CCONJ', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5255
# Combo: ('AUX', 'CCONJ', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5265
# Combo: ('AUX', 'CCONJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5312
# Combo: ('AUX', 'CCONJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5290
# Combo: ('AUX', 'CCONJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5289
# Combo: ('AUX', 'CCONJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5323
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ') -> Accuracy: 0.5436
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'ADJ') -> Accuracy: 0.5426
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'NOUN') -> Accuracy: 0.5483
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'ADV') -> Accuracy: 0.5417
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'PROPN') -> Accuracy: 0.5406
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'ADP') -> Accuracy: 0.5393
# Combo: ('AUX', 'INTJ', 'PRON', 'SCONJ', 'ADJ') -> Accuracy: 0.5341
# Combo: ('AUX', 'INTJ', 'PRON', 'SCONJ', 'NOUN') -> Accuracy: 0.5314
# Combo: ('AUX', 'INTJ', 'PRON', 'SCONJ', 'ADV') -> Accuracy: 0.5309
# Combo: ('AUX', 'INTJ', 'PRON', 'SCONJ', 'PROPN') -> Accuracy: 0.5307
# Combo: ('AUX', 'INTJ', 'PRON', 'SCONJ', 'ADP') -> Accuracy: 0.5281
# Combo: ('AUX', 'INTJ', 'PRON', 'ADJ', 'NOUN') -> Accuracy: 0.5392
# Combo: ('AUX', 'INTJ', 'PRON', 'ADJ', 'ADV') -> Accuracy: 0.5300
# Combo: ('AUX', 'INTJ', 'PRON', 'ADJ', 'PROPN') -> Accuracy: 0.5362
# Combo: ('AUX', 'INTJ', 'PRON', 'ADJ', 'ADP') -> Accuracy: 0.5349
# Combo: ('AUX', 'INTJ', 'PRON', 'NOUN', 'ADV') -> Accuracy: 0.5285
# Combo: ('AUX', 'INTJ', 'PRON', 'NOUN', 'PROPN') -> Accuracy: 0.5364
# Combo: ('AUX', 'INTJ', 'PRON', 'NOUN', 'ADP') -> Accuracy: 0.5370
# Combo: ('AUX', 'INTJ', 'PRON', 'ADV', 'PROPN') -> Accuracy: 0.5324
# Combo: ('AUX', 'INTJ', 'PRON', 'ADV', 'ADP') -> Accuracy: 0.5301
# Combo: ('AUX', 'INTJ', 'PRON', 'PROPN', 'ADP') -> Accuracy: 0.5272
# Combo: ('AUX', 'INTJ', 'VERB', 'SCONJ', 'ADJ') -> Accuracy: 0.5309
# Combo: ('AUX', 'INTJ', 'VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5395
# Combo: ('AUX', 'INTJ', 'VERB', 'SCONJ', 'ADV') -> Accuracy: 0.5342
# Combo: ('AUX', 'INTJ', 'VERB', 'SCONJ', 'PROPN') -> Accuracy: 0.5353
# Combo: ('AUX', 'INTJ', 'VERB', 'SCONJ', 'ADP') -> Accuracy: 0.5262
# Combo: ('AUX', 'INTJ', 'VERB', 'ADJ', 'NOUN') -> Accuracy: 0.5293
# Combo: ('AUX', 'INTJ', 'VERB', 'ADJ', 'ADV') -> Accuracy: 0.5312
# Combo: ('AUX', 'INTJ', 'VERB', 'ADJ', 'PROPN') -> Accuracy: 0.5317
# Combo: ('AUX', 'INTJ', 'VERB', 'ADJ', 'ADP') -> Accuracy: 0.5275
# Combo: ('AUX', 'INTJ', 'VERB', 'NOUN', 'ADV') -> Accuracy: 0.5370
# Combo: ('AUX', 'INTJ', 'VERB', 'NOUN', 'PROPN') -> Accuracy: 0.5397
# Combo: ('AUX', 'INTJ', 'VERB', 'NOUN', 'ADP') -> Accuracy: 0.5341
# Combo: ('AUX', 'INTJ', 'VERB', 'ADV', 'PROPN') -> Accuracy: 0.5333
# Combo: ('AUX', 'INTJ', 'VERB', 'ADV', 'ADP') -> Accuracy: 0.5281
# Combo: ('AUX', 'INTJ', 'VERB', 'PROPN', 'ADP') -> Accuracy: 0.5285
# Combo: ('AUX', 'INTJ', 'SCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5317
# Combo: ('AUX', 'INTJ', 'SCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5328
# Combo: ('AUX', 'INTJ', 'SCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5310
# Combo: ('AUX', 'INTJ', 'SCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5205
# Combo: ('AUX', 'INTJ', 'SCONJ', 'NOUN', 'ADV') -> Accuracy: 0.5285
# Combo: ('AUX', 'INTJ', 'SCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5363
# Combo: ('AUX', 'INTJ', 'SCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5317
# Combo: ('AUX', 'INTJ', 'SCONJ', 'ADV', 'PROPN') -> Accuracy: 0.5376
# Combo: ('AUX', 'INTJ', 'SCONJ', 'ADV', 'ADP') -> Accuracy: 0.5298
# Combo: ('AUX', 'INTJ', 'SCONJ', 'PROPN', 'ADP') -> Accuracy: 0.5347
# Combo: ('AUX', 'INTJ', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5254
# Combo: ('AUX', 'INTJ', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5359
# Combo: ('AUX', 'INTJ', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5302
# Combo: ('AUX', 'INTJ', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5341
# Combo: ('AUX', 'INTJ', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5285
# Combo: ('AUX', 'INTJ', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5319
# Combo: ('AUX', 'INTJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5333
# Combo: ('AUX', 'INTJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5298
# Combo: ('AUX', 'INTJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5316
# Combo: ('AUX', 'INTJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5374
# Combo: ('AUX', 'PRON', 'VERB', 'SCONJ', 'ADJ') -> Accuracy: 0.5367
# Combo: ('AUX', 'PRON', 'VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5437
# Combo: ('AUX', 'PRON', 'VERB', 'SCONJ', 'ADV') -> Accuracy: 0.5426
# Combo: ('AUX', 'PRON', 'VERB', 'SCONJ', 'PROPN') -> Accuracy: 0.5403
# Combo: ('AUX', 'PRON', 'VERB', 'SCONJ', 'ADP') -> Accuracy: 0.5371
# Combo: ('AUX', 'PRON', 'VERB', 'ADJ', 'NOUN') -> Accuracy: 0.5375
# Combo: ('AUX', 'PRON', 'VERB', 'ADJ', 'ADV') -> Accuracy: 0.5358
# Combo: ('AUX', 'PRON', 'VERB', 'ADJ', 'PROPN') -> Accuracy: 0.5370
# Combo: ('AUX', 'PRON', 'VERB', 'ADJ', 'ADP') -> Accuracy: 0.5312
# Combo: ('AUX', 'PRON', 'VERB', 'NOUN', 'ADV') -> Accuracy: 0.5393
# Combo: ('AUX', 'PRON', 'VERB', 'NOUN', 'PROPN') -> Accuracy: 0.5435
# Combo: ('AUX', 'PRON', 'VERB', 'NOUN', 'ADP') -> Accuracy: 0.5354
# Combo: ('AUX', 'PRON', 'VERB', 'ADV', 'PROPN') -> Accuracy: 0.5400
# Combo: ('AUX', 'PRON', 'VERB', 'ADV', 'ADP') -> Accuracy: 0.5353
# Combo: ('AUX', 'PRON', 'VERB', 'PROPN', 'ADP') -> Accuracy: 0.5320
# Combo: ('AUX', 'PRON', 'SCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5325
# Combo: ('AUX', 'PRON', 'SCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5336
# Combo: ('AUX', 'PRON', 'SCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5327
# Combo: ('AUX', 'PRON', 'SCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5288
# Combo: ('AUX', 'PRON', 'SCONJ', 'NOUN', 'ADV') -> Accuracy: 0.5296
# Combo: ('AUX', 'PRON', 'SCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5360
# Combo: ('AUX', 'PRON', 'SCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5323
# Combo: ('AUX', 'PRON', 'SCONJ', 'ADV', 'PROPN') -> Accuracy: 0.5297
# Combo: ('AUX', 'PRON', 'SCONJ', 'ADV', 'ADP') -> Accuracy: 0.5282
# Combo: ('AUX', 'PRON', 'SCONJ', 'PROPN', 'ADP') -> Accuracy: 0.5265
# Combo: ('AUX', 'PRON', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5307
# Combo: ('AUX', 'PRON', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5316
# Combo: ('AUX', 'PRON', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5325
# Combo: ('AUX', 'PRON', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5333
# Combo: ('AUX', 'PRON', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5293
# Combo: ('AUX', 'PRON', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5306
# Combo: ('AUX', 'PRON', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5312
# Combo: ('AUX', 'PRON', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5315
# Combo: ('AUX', 'PRON', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5352
# Combo: ('AUX', 'PRON', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5235
# Combo: ('AUX', 'VERB', 'SCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5269
# Combo: ('AUX', 'VERB', 'SCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5301
# Combo: ('AUX', 'VERB', 'SCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5259
# Combo: ('AUX', 'VERB', 'SCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5268
# Combo: ('AUX', 'VERB', 'SCONJ', 'NOUN', 'ADV') -> Accuracy: 0.5330
# Combo: ('AUX', 'VERB', 'SCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5379
# Combo: ('AUX', 'VERB', 'SCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5352
# Combo: ('AUX', 'VERB', 'SCONJ', 'ADV', 'PROPN') -> Accuracy: 0.5346
# Combo: ('AUX', 'VERB', 'SCONJ', 'ADV', 'ADP') -> Accuracy: 0.5308
# Combo: ('AUX', 'VERB', 'SCONJ', 'PROPN', 'ADP') -> Accuracy: 0.5261
# Combo: ('AUX', 'VERB', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5287
# Combo: ('AUX', 'VERB', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5265
# Combo: ('AUX', 'VERB', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5276
# Combo: ('AUX', 'VERB', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5319
# Combo: ('AUX', 'VERB', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5303
# Combo: ('AUX', 'VERB', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5242
# Combo: ('AUX', 'VERB', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5330
# Combo: ('AUX', 'VERB', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5331
# Combo: ('AUX', 'VERB', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5363
# Combo: ('AUX', 'VERB', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5273
# Combo: ('AUX', 'SCONJ', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5221
# Combo: ('AUX', 'SCONJ', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5272
# Combo: ('AUX', 'SCONJ', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5205
# Combo: ('AUX', 'SCONJ', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5343
# Combo: ('AUX', 'SCONJ', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5292
# Combo: ('AUX', 'SCONJ', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5270
# Combo: ('AUX', 'SCONJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5282
# Combo: ('AUX', 'SCONJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5256
# Combo: ('AUX', 'SCONJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5278
# Combo: ('AUX', 'SCONJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5346
# Combo: ('AUX', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5250
# Combo: ('AUX', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5234
# Combo: ('AUX', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5229
# Combo: ('AUX', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5305
# Combo: ('AUX', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5319
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ') -> Accuracy: 0.5349
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'ADJ') -> Accuracy: 0.5330
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'NOUN') -> Accuracy: 0.5383
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'ADV') -> Accuracy: 0.5353
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'PROPN') -> Accuracy: 0.5318
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'ADP') -> Accuracy: 0.5302
# Combo: ('CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADJ') -> Accuracy: 0.5312
# Combo: ('CCONJ', 'INTJ', 'PRON', 'SCONJ', 'NOUN') -> Accuracy: 0.5317
# Combo: ('CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADV') -> Accuracy: 0.5240
# Combo: ('CCONJ', 'INTJ', 'PRON', 'SCONJ', 'PROPN') -> Accuracy: 0.5257
# Combo: ('CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADP') -> Accuracy: 0.5305
# Combo: ('CCONJ', 'INTJ', 'PRON', 'ADJ', 'NOUN') -> Accuracy: 0.5339
# Combo: ('CCONJ', 'INTJ', 'PRON', 'ADJ', 'ADV') -> Accuracy: 0.5271
# Combo: ('CCONJ', 'INTJ', 'PRON', 'ADJ', 'PROPN') -> Accuracy: 0.5283
# Combo: ('CCONJ', 'INTJ', 'PRON', 'ADJ', 'ADP') -> Accuracy: 0.5321
# Combo: ('CCONJ', 'INTJ', 'PRON', 'NOUN', 'ADV') -> Accuracy: 0.5256
# Combo: ('CCONJ', 'INTJ', 'PRON', 'NOUN', 'PROPN') -> Accuracy: 0.5313
# Combo: ('CCONJ', 'INTJ', 'PRON', 'NOUN', 'ADP') -> Accuracy: 0.5305
# Combo: ('CCONJ', 'INTJ', 'PRON', 'ADV', 'PROPN') -> Accuracy: 0.5267
# Combo: ('CCONJ', 'INTJ', 'PRON', 'ADV', 'ADP') -> Accuracy: 0.5284
# Combo: ('CCONJ', 'INTJ', 'PRON', 'PROPN', 'ADP') -> Accuracy: 0.5237
# Combo: ('CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADJ') -> Accuracy: 0.5254
# Combo: ('CCONJ', 'INTJ', 'VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5300
# Combo: ('CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADV') -> Accuracy: 0.5265
# Combo: ('CCONJ', 'INTJ', 'VERB', 'SCONJ', 'PROPN') -> Accuracy: 0.5309
# Combo: ('CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADP') -> Accuracy: 0.5272
# Combo: ('CCONJ', 'INTJ', 'VERB', 'ADJ', 'NOUN') -> Accuracy: 0.5249
# Combo: ('CCONJ', 'INTJ', 'VERB', 'ADJ', 'ADV') -> Accuracy: 0.5306
# Combo: ('CCONJ', 'INTJ', 'VERB', 'ADJ', 'PROPN') -> Accuracy: 0.5296
# Combo: ('CCONJ', 'INTJ', 'VERB', 'ADJ', 'ADP') -> Accuracy: 0.5245
# Combo: ('CCONJ', 'INTJ', 'VERB', 'NOUN', 'ADV') -> Accuracy: 0.5318
# Combo: ('CCONJ', 'INTJ', 'VERB', 'NOUN', 'PROPN') -> Accuracy: 0.5383
# Combo: ('CCONJ', 'INTJ', 'VERB', 'NOUN', 'ADP') -> Accuracy: 0.5232
# Combo: ('CCONJ', 'INTJ', 'VERB', 'ADV', 'PROPN') -> Accuracy: 0.5341
# Combo: ('CCONJ', 'INTJ', 'VERB', 'ADV', 'ADP') -> Accuracy: 0.5295
# Combo: ('CCONJ', 'INTJ', 'VERB', 'PROPN', 'ADP') -> Accuracy: 0.5284
# Combo: ('CCONJ', 'INTJ', 'SCONJ', 'ADJ', 'NOUN') -> Accuracy: 0.5270
# Combo: ('CCONJ', 'INTJ', 'SCONJ', 'ADJ', 'ADV') -> Accuracy: 0.5266
# Combo: ('CCONJ', 'INTJ', 'SCONJ', 'ADJ', 'PROPN') -> Accuracy: 0.5249
# Combo: ('CCONJ', 'INTJ', 'SCONJ', 'ADJ', 'ADP') -> Accuracy: 0.5224
# ...
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5469
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5411
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5423
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5392
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5457
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5464
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5444
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5413
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5457
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5464
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5478
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5403
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5500
# Combo: ('AUX', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5404
# Combo: ('AUX', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5332
# Combo: ('AUX', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5349
# Combo: ('AUX', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5292
# Combo: ('AUX', 'INTJ', 'PRON', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5354
# Combo: ('AUX', 'INTJ', 'PRON', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5353
# Combo: ('AUX', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5331
# Combo: ('AUX', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5351
# Combo: ('AUX', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5364
# Combo: ('AUX', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5311
# Combo: ('AUX', 'INTJ', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5379
# Combo: ('AUX', 'INTJ', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5369
# Combo: ('AUX', 'INTJ', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5278
# Combo: ('AUX', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5416
# Combo: ('AUX', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5423
# Combo: ('AUX', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5445
# Combo: ('AUX', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5347
# Combo: ('AUX', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5460
# Combo: ('AUX', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5397
# Combo: ('AUX', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5314
# Combo: ('AUX', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5375
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5386
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5373
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5414
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5361
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5398
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5325
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5366
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5372
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5399
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5378
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5359
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5415
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5403
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5382
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5390
# Combo: ('CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5368
# Combo: ('CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5350
# Combo: ('CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5394
# Combo: ('CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5308
# Combo: ('CCONJ', 'INTJ', 'PRON', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5388
# Combo: ('CCONJ', 'INTJ', 'PRON', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5306
# Combo: ('CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5324
# Combo: ('CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5294
# Combo: ('CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5288
# Combo: ('CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5371
# Combo: ('CCONJ', 'INTJ', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5314
# Combo: ('CCONJ', 'INTJ', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5329
# Combo: ('CCONJ', 'INTJ', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5239
# Combo: ('CCONJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5318
# Combo: ('CCONJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5391
# Combo: ('CCONJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5370
# Combo: ('CCONJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5338
# Combo: ('CCONJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5396
# Combo: ('CCONJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5365
# Combo: ('CCONJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5307
# Combo: ('CCONJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5253
# Combo: ('INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5372
# Combo: ('INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5440
# Combo: ('INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5393
# Combo: ('INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5354
# Combo: ('INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5401
# Combo: ('INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5385
# Combo: ('INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5303
# Combo: ('INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5327
# Combo: ('PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5394
#
# --- Subset Size: 9 ---
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV') -> Accuracy: 0.5458
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5444
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADP') -> Accuracy: 0.5462
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN') -> Accuracy: 0.5403
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'ADP') -> Accuracy: 0.5453
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'PROPN', 'ADP') -> Accuracy: 0.5384
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5465
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5463
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5484
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5397
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5453
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5476
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5455
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5398
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5479
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5381
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5398
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5402
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5312
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5387
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5382
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5381
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5373
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5390
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5355
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5376
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5375
# Combo: ('AUX', 'CCONJ', 'INTJ', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5283
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5451
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5464
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5410
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5389
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5468
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5405
# Combo: ('AUX', 'CCONJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5365
# Combo: ('AUX', 'CCONJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5339
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5482
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5508
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5465
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5400
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5535
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5432
# Combo: ('AUX', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5373
# Combo: ('AUX', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5352
# Combo: ('AUX', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5433
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5342
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5423
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5398
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5382
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5436
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5376
# Combo: ('CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5345
# Combo: ('CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5323
# Combo: ('CCONJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5379
# Combo: ('INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5404
#
# --- Subset Size: 10 ---
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN') -> Accuracy: 0.5452
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5479
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'PROPN', 'ADP') -> Accuracy: 0.5437
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5373
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5501
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5457
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5404
# Combo: ('AUX', 'CCONJ', 'INTJ', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5361
# Combo: ('AUX', 'CCONJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5478
# Combo: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5456
# Combo: ('CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5399
#
# --- Subset Size: 11 ---
# Combo: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5474
#
# Top 10 Combinations:
# 1. Tags: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5535
# 2. Tags: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5516
# 3. Tags: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'ADP') -> Accuracy: 0.5508
# 4. Tags: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5503
# 5. Tags: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5501
# 6. Tags: ('AUX', 'INTJ', 'PRON', 'VERB', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5500
# 7. Tags: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'PROPN') -> Accuracy: 0.5492
# 8. Tags: ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADP') -> Accuracy: 0.5491
# 9. Tags: ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5490
# 10. Tags: ('AUX', 'INTJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'PROPN') -> Accuracy: 0.5490
#
# Best combination per subset size:
# Size 1: Tags ('AUX',) -> Accuracy: 0.5298
# Size 2: Tags ('AUX', 'INTJ') -> Accuracy: 0.5340
# Size 3: Tags ('AUX', 'PRON', 'VERB') -> Accuracy: 0.5390
# Size 4: Tags ('AUX', 'INTJ', 'PRON', 'VERB') -> Accuracy: 0.5420
# Size 5: Tags ('AUX', 'INTJ', 'PRON', 'VERB', 'NOUN') -> Accuracy: 0.5483
# Size 6: Tags ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5516
# Size 7: Tags ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN') -> Accuracy: 0.5503
# Size 8: Tags ('AUX', 'INTJ', 'PRON', 'VERB', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5500
# Size 9: Tags ('AUX', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5535
# Size 10: Tags ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5501
# Size 11: Tags ('AUX', 'CCONJ', 'INTJ', 'PRON', 'VERB', 'SCONJ', 'ADJ', 'NOUN', 'ADV', 'PROPN', 'ADP') -> Accuracy: 0.5474
